# %% [markdown]
# # Word Accentuation

# %%
import json
import re
import requests
import time
from collections import Counter
from functools import lru_cache
from pathlib import Path

import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
liepa_path = Path("../data/raw/liepa2/")

# Get all train parquet files
train_files = sorted(liepa_path.glob("train-*.parquet"))
print(f"Found {len(train_files)} training parquet files")

# Load and concatenate all training data
dfs = []
for file_path in tqdm(train_files, desc="Loading parquet files"):
    df = pd.read_parquet(file_path)
    dfs.append(df)

# Combine all dataframes
full_df = pd.concat(dfs, ignore_index=True)
full_df["path"] = full_df["audio"].apply(lambda x: x["path"])
full_df.drop(columns=["audio"], inplace=True)
full_df.sort_values("path", inplace=True)
# Out:
# Found 130 training parquet files
# Loading parquet files: 100%|██████████| 130/130 [00:42<00:00,  3.06it/s]

# %% [markdown]
# ## Scrape Kirčiuoklis

# %%
def extract_all_words(text):
    text = re.sub(r"([^\w\s]|[ʻʼ])", " ", text)
    words = text.split()
    return words

# %%
extract_all_words("ʻąžuolasʼ, ąžuolas - beržas !")
# Out:
# ['ąžuolas', 'ąžuolas', 'beržas']

# %%
all_words = [
    word
    for text in tqdm(full_df["sentence"].tolist(), desc="Extracting words")
    for word in extract_all_words(text)
]
all_words_df = pd.Series(all_words).value_counts().to_frame("count")
# Out:
# Extracting words:   0%|          | 0/1132528 [00:00<?, ?it/s]
# Extracting words: 100%|██████████| 1132528/1132528 [00:03<00:00, 327283.58it/s]

# %%
# all_words_df[all_words_df.index.str.contains(r"[^a-zA-ZąčęėįšųūžĄČĘĖĮŠŲŪŽ]", regex=True)]

# %%
@lru_cache(maxsize=None)
def request_accents(words):
    response = requests.post(
        "https://kalbu.vdu.lt/ajax-call",
        headers={"Content-Type": "application/x-www-form-urlencoded; charset=UTF-8"},
        data={"action": "text_accents", "body": " ".join(words)},
    )
    accented_text = response.text
    content = json.loads(response.json()["message"])["textParts"]
    time.sleep(0.3)
    return content

# %%
all_contents = []
banned_words = ["užsižiops", "nepasidūs"]

for chunk in tqdm(
    np.array_split(all_words_df.index, len(all_words_df) // 200),
    desc="Processing chunks",
):
    try:
        content = request_accents(
            tuple(word for word in chunk if word not in banned_words)
        )
    except Exception as e:
        print(f"Error processing chunk: {e}")
        print(tuple(chunk))
        content = []
    all_contents.extend(content)

# %%
accents_df
# Out:
#                   string           accented        accentType  type
# 0                     ir                ir̃               ONE  WORD
# 1                    kad               kàd               ONE  WORD
# 2                      į                 į̃               ONE  WORD
# 3                    tai               taĩ  MULTIPLE_MEANING  WORD
# 4                     iš                ìš               ONE  WORD
# ...                  ...                ...               ...   ...
# 446455      vadovėlinius      vadovė̃linius               ONE  WORD
# 446456     nebesipyksime     nebesipỹksime               ONE  WORD
# 446457  virpčiojančiomis  vìrpčiojančiomis               ONE  WORD
# 446458         gailėjęsi         gailė́jęsi               ONE  WORD
# 446459         evakavosi         evakãvosi               ONE  WORD
#
# [446460 rows x 4 columns]

# %%
accents_df = pd.read_csv("accented_words.csv", keep_default_na=False)
accents_df = pd.concat([accents_df, pd.DataFrame({""})])

# %%
# accents_df = pd.DataFrame(all_contents)
# accents_df = accents_df[accents_df["string"] != " "].reset_index(drop=True)

# accents_df.to_csv("accented_words.csv", index=False)

# %%
# concat columns
words_accents_df = pd.merge(
    all_words_df,
    accents_df,
    # how="left",
    left_index=True,
    right_on="string",
)

# %%
# words_accents_df["accentType"].value_counts()

# %%
# words_accents_df[words_accents_df["accentType"] == ""]

# %%
# words_accents_df[words_accents_df["accentType"] == "NONE"].head(20)

# %%
full_df[full_df["sentence"].str.contains(r"x", regex=True)]
# Out:
#                                                   sentence language  \
# 558124   jau buvau bepradedanti nerimauti tikėjausi kad...       lt
# 1090112  Laikas prie jo tirpte tirpdavo ypač kai atsira...       lt
# 211790   patys vargingiausi kokius išgyveno tas kraštas...       lt
# 162746                       su profesoriumi Toru Kawasaki       lt
# 150258   Paskui Toru Kawasaki veža mane į Waseda univer...       lt
# 93533                        Kaligrafo Sugiwaros paslaptys       lt
# 872633                             paskui Owakidani slėnis       lt
# 147641   dėvėjo snapeliu atgal apsukta New York Yankees...       lt
# 573664       Ar žinote, kuo ypatingas paketas Always Ultra       lt
# 535564   Jis teigia, kad pirmasis visiems priimtiną kul...       lt
# 966301   kaip turėtų būti baisinga likti mandagiam su d...       lt
# 98682                      įgaliotasis Volkswagen servisas       lt
# 826692   nes apie tai savo laiku buvo rašyta laikraštyj...       lt
# 1026379  tūkstantis devyni šimtai aštuoniasdešimt ketvi...       lt
# 352182   o pro virpančius virš jo galvos mw medžio lapu...       lt
# 176929   dvyliktame tryliktame amwiuje įsigali palaikų ...       lt
# 176852                                  iwtai kur yra mūsų       lt
# 698602             Kažkoks nonsensas Panaršiau draugo webą       lt
# 295189   Panaršiau draugo webą man patiko Šiaip reikėtų...       lt
# 356579   sako Ianas Howarthas iš Londono universiteto k...       lt
# 629426                                      Kefi Klyrwoter       lt
# 269318   šią kolekciją pastebėjo ir nupirko garsi stili...       lt
# 67445                       Top šešiolika kompanys tiu woč       lt
#
#                                 path
# 558124   L_RA_F4_IS026_01_000796.mp3
# 1090112  L_RA_M4_DK006_01_000227.mp3
# 211790   L_RA_M4_IS016_01_000472.mp3
# 162746   L_RS_F5_AS019_01_000163.mp3
# 150258   L_RS_F5_AS019_01_000313.mp3
# 93533    L_RS_F5_AS019_01_000333.mp3
# 872633   L_RS_F5_AS019_01_001045.mp3
# 147641   L_RS_M4_AS026_01_000949.mp3
# 573664   R_RD_F3_AS115_01_000032.mp3
# 535564   R_RD_F4_MS010_01_000111.mp3
# 966301   R_RS_F1_IS289_01_000145.mp3
# 98682    R_RS_F4_AS047_01_000210.mp3
# 826692   R_RS_F4_AS097_01_000343.mp3
# 1026379  R_RS_F4_BG180_01_000036.mp3
# 352182   R_RS_M1_MS259_01_000509.mp3
# 176929   R_RS_M4_IS045_01_000158.mp3
# 176852   R_RS_M4_IS396_01_000097.mp3
# 698602   R_RS_M4_MS062_01_000625.mp3
# 295189   R_RS_M4_MS062_01_000627.mp3
# 356579   R_RS_M4_VK067_01_000477.mp3
# 629426   R_RT_M3_VK207_01_000064.mp3
# 269318   R_SD_F4_MS138_01_000035.mp3
# 67445    R_SD_M4_IM188_01_000074.mp3

# %%
words_accents_df.groupby("accentType")["count"].sum()
# Out:
# accentType
#                         275
# MULTIPLE_MEANING     977437
# MULTIPLE_VARIANT      66246
# NONE                 230003
# ONE                 5402357
# Name: count, dtype: int64

# %%
# words_accents_df["accentType"].value_counts()

# %%
words_accents_df["accented"] = words_accents_df["accented"].str.translate(
    {ord("̃"): "~", ord("̀"): "`", ord("́"): "´"}
)

# %%
# Counter("".join(words_accents_df["accented"]))

# %%
final_accents_df = words_accents_df[words_accents_df["accentType"] == "ONE"][
    ["string", "accented"]
]
final_accents_df.to_csv(liepa_path / "final_accented_words.csv", index=False)
